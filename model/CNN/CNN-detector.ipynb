# %%
import torch 
from torchvision import datasets
from torch import nn
import platform
from torchinfo import summary

# %%
if platform.system().lower() == 'windows':
    DATA_PATH = 'C:\\Users\\MK9\\Projects\\python__object-detection\\raw\\training_data_48x48'

# %%
class CNNBubbleDetector(nn.Module):
    def __init__(self) -> None:
        super().__init__()
        self.flatten = nn.Flatten()
        
        self.feature = nn.Sequential(
            # input: rgb 3 channels
            
            # [bs, 3, 48, 48] --> [bs, 8, 44, 44]
            nn.Conv2d(3, 8, 5), 
            
            # [bs, 8, 44, 44] --> [bs, 8, 22, 22]
            nn.MaxPool2d(2),
            
            # [bs, 8, 22, 22] --> [bs, 16, 18, 18]
            nn.Conv2d(8, 16, 5),
            
            # [bs, 16, 18, 18] --> [bs, 16, 9, 9]
            nn.MaxPool2d(2)
        )
        
        self.fc = nn.Sequential(
            nn.Linear(16*9*9, 75), 
            nn.ReLU(), 
            nn.Linear(75, 1)
        )
        
        
    def forward(self, x):
        x = self.feature(x)
        x = self.flatten(x)
        x = self.fc(x)
        return torch.sigmoid(x)

# %%
cnn_bubble_detector = CNNBubbleDetector()
summary(cnn_bubble_detector, input_size=[10, 3, 48, 48])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CNNBubbleDetector                        --                        --
# ├─Sequential: 1-1                        [10, 16, 9, 9]            --
# │    └─Conv2d: 2-1                       [10, 8, 44, 44]           608
# │    └─MaxPool2d: 2-2                    [10, 8, 22, 22]           --
# │    └─Conv2d: 2-3                       [10, 16, 18, 18]          3,216
# │    └─MaxPool2d: 2-4                    [10, 16, 9, 9]            --
# ├─Flatten: 1-2                           [10, 1296]                --
# ├─Sequential: 1-3                        [10, 1]                   --
# │    └─Linear: 2-5                       [10, 75]                  97,275
# │    └─ReLU: 2-6                         [10, 75]                  --
# │    └─Linear: 2-7                       [10, 1]                   76
# ==========================================================================================
# Total params: 101,175
# Trainable params: 101,175
# Non-trainable params: 0
# Total mult-adds (M): 23.16
# ==========================================================================================
# Input size (MB): 0.28
# Forward/backward pass size (MB): 1.66
# Params size (MB): 0.40
# Estimated Total Size (MB): 2.34
# ==========================================================================================

# %%
from torchvision.datasets import ImageFolder
import torchvision.transforms as T

img_transform = {
    'train': T.Compose([
        T.RandomRotation(degrees=15), 
        T.RandomHorizontalFlip(), 
        T.ToTensor()
    ]), 
    
    'valid': T.Compose([
        T.ToTensor()
    ]), 
    
    'test': T.Compose([
        T.ToTensor()
    ])
}

bubble_dataset = ImageFolder(DATA_PATH, transform=T.ToTensor())
print(len(bubble_dataset))
# Out:
# 1393

# %%
train_len = int(0.8 * len(bubble_dataset))
valid_len = len(bubble_dataset) - train_len
train_data, valid_data = torch.utils.data.random_split(bubble_dataset, [train_len, valid_len])
print(len(train_data), len(valid_data), len(bubble_dataset))
train_data.dataset.transform = img_transform['train']
# Out:
# 1114 279 1393

# %%
sum([train_data[i][1] for i in range(len(train_data))])
# Out:
# 79

# %%
from torch.utils.data import DataLoader
train_dataloader = DataLoader(train_data, batch_size=32)
valid_dataloader = DataLoader(valid_data, batch_size=32)

# %%
X = torch.rand(10, 3, 48, 48)
pred = cnn_bubble_detector(X)

# %%
pred
# Out:
# tensor([[0.4865],
#         [0.4833],
#         [0.4870],
#         [0.4890],
#         [0.4856],
#         [0.4889],
#         [0.4835],
#         [0.4861],
#         [0.4824],
#         [0.4862]], grad_fn=<SigmoidBackward0>)

# %%
from torch import optim
import numpy as np

loss_func = nn.BCELoss()
optimizer = optim.Adam(cnn_bubble_detector.parameters(), lr=0.001)


def train_loop(dataloader, model, loss_fn, optimizer):  
    data_size = len(dataloader.dataset) 
    
    # Set to training mode
    model.train()
    
    for batch, (X, y) in enumerate(dataloader):
        
        # forward pass
        pred = model(X)
        y = y.unsqueeze(1).float()
        loss = loss_fn(pred, y)
        
        # backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # display progress
        if batch % 10 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}, [{current:>d}]/[{data_size:>d}]")
            
            
def valid_loop(dataloader, model, loss_fn):
    
    # Set to evaluation mode
    model.eval()
    
    data_size = len(dataloader.dataset)
    valid_loss, correct = 0, 0
    
    with torch.no_grad():
        for (X, y) in dataloader:
            pred = model(X)
            
            valid_loss += loss_fn(pred, y.unsqueeze(1).float()).item()
            correct += (pred[:,0] > .5).type(torch.float64).sum().item()
    
    valid_loss /= data_size
    correct /= data_size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {valid_loss:>8f}\n")
        
        
# Start trainning
epochs = 300
for epoch in range(epochs):
    print(f"Epoch: {epoch+1}/{epochs}\n------------------------------------------")
    train_loop(train_dataloader, cnn_bubble_detector, loss_func, optimizer)
    valid_loop(valid_dataloader, cnn_bubble_detector, loss_func)
# Out:
# Epoch: 1/300
# ------------------------------------------
# loss: 0.003167, [0]/[1114]
# loss: 0.008933, [320]/[1114]
# loss: 0.014678, [640]/[1114]
# loss: 0.073124, [960]/[1114]
# Test Error:
#  Accuracy: 5.4%, Avg loss: 0.005915
#
# Epoch: 2/300
# ------------------------------------------
# loss: 0.001743, [0]/[1114]
# loss: 0.010941, [320]/[1114]
# loss: 0.011032, [640]/[1114]
# loss: 0.022165, [960]/[1114]
# Test Error:
#  Accuracy: 5.0%, Avg loss: 0.006616
#
# Epoch: 3/300
# ------------------------------------------
# loss: 0.064267, [0]/[1114]
# loss: 0.003051, [320]/[1114]
# loss: 0.017033, [640]/[1114]
# loss: 0.033196, [960]/[1114]
# Test Error:
#  Accuracy: 6.1%, Avg loss: 0.005030
#
# Epoch: 4/300
# ------------------------------------------
# loss: 0.041819, [0]/[1114]
# loss: 0.013377, [320]/[1114]
# loss: 0.009731, [640]/[1114]
# loss: 0.098691, [960]/[1114]
# Test Error:
#  Accuracy: 6.1%, Avg loss: 0.004456
#
# Epoch: 5/300
# ------------------------------------------
# loss: 0.007378, [0]/[1114]
# loss: 0.001734, [320]/[1114]
# loss: 0.027295, [640]/[1114]
# loss: 0.017046, [960]/[1114]
# Test Error:
#  Accuracy: 6.5%, Avg loss: 0.003505
#
# Epoch: 6/300
# ------------------------------------------
# loss: 0.006914, [0]/[1114]
# loss: 0.001720, [320]/[1114]
# loss: 0.013176, [640]/[1114]
# loss: 0.003694, [960]/[1114]
# Test Error:
#  Accuracy: 5.0%, Avg loss: 0.005562
#
# Epoch: 7/300
# ------------------------------------------
# loss: 0.054932, [0]/[1114]
# loss: 0.018197, [320]/[1114]
# loss: 0.002675, [640]/[1114]
# loss: 0.013251, [960]/[1114]
# Test Error:
#  Accuracy: 6.1%, Avg loss: 0.004549
#
# Epoch: 8/300
# ------------------------------------------
# loss: 0.022790, [0]/[1114]
# loss: 0.004110, [320]/[1114]
# loss: 0.026352, [640]/[1114]
# loss: 0.010263, [960]/[1114]
# Test Error:
#  Accuracy: 5.0%, Avg loss: 0.005408
#
# Epoch: 9/300
# ------------------------------------------
# loss: 0.048298, [0]/[1114]
# loss: 0.002514, [320]/[1114]
# loss: 0.113441, [640]/[1114]
# loss: 0.027858, [960]/[1114]
# Test Error:
#  Accuracy: 5.7%, Avg loss: 0.005832
#
# Epoch: 10/300
# ------------------------------------------
# loss: 0.002405, [0]/[1114]
# loss: 0.003468, [320]/[1114]
# loss: 0.013496, [640]/[1114]
# loss: 0.009302, [960]/[1114]
# Test Error:
#  Accuracy: 6.1%, Avg loss: 0.005213
#
# Epoch: 11/300
# ------------------------------------------
# loss: 0.000576, [0]/[1114]
# loss: 0.000367, [320]/[1114]
# loss: 0.004109, [640]/[1114]
# loss: 0.005969, [960]/[1114]
# Test Error:
#  Accuracy: 5.4%, Avg loss: 0.004718
#
# Epoch: 12/300
# ------------------------------------------
# loss: 0.051114, [0]/[1114]
# loss: 0.005975, [320]/[1114]
# loss: 0.007062, [640]/[1114]
# loss: 0.044756, [960]/[1114]
# Test Error:
#  Accuracy: 5.7%, Avg loss: 0.005843
#
# Epoch: 13/300
# ------------------------------------------
# loss: 0.056252, [0]/[1114]
# loss: 0.006459, [320]/[1114]
# loss: 0.007362, [640]/[1114]
# loss: 0.011642, [960]/[1114]
# Test Error:
#  Accuracy: 6.1%, Avg loss: 0.005899
#
# Epoch: 14/300
# ------------------------------------------
# loss: 0.005422, [0]/[1114]
# loss: 0.001706, [320]/[1114]
# loss: 0.004981, [640]/[1114]
# loss: 0.006510, [960]/[1114]
# Test Error:
#  Accuracy: 6.8%, Avg loss: 0.005505
#
# Epoch: 15/300
# ------------------------------------------
# loss: 0.001436, [0]/[1114]
# loss: 0.003395, [320]/[1114]
# loss: 0.003634, [640]/[1114]
# loss: 0.072046, [960]/[1114]
# Test Error:
#  Accuracy: 5.7%, Avg loss: 0.006599
#
# Epoch: 16/300
# ------------------------------------------
# loss: 0.041652, [0]/[1114]
# loss: 0.009038, [320]/[1114]
# loss: 0.016953, [640]/[1114]
# loss: 0.008100, [960]/[1114]
# Test Error:
#  Accuracy: 6.5%, Avg loss: 0.004912
#
# Epoch: 17/300
# ------------------------------------------
# loss: 0.004794, [0]/[1114]
# loss: 0.000749, [320]/[1114]
# loss: 0.022941, [640]/[1114]
# loss: 0.004366, [960]/[1114]
# Test Error:
#  Accuracy: 6.1%, Avg loss: 0.006150
#
# Epoch: 18/300
# ------------------------------------------
# loss: 0.047698, [0]/[1114]
# loss: 0.007148, [320]/[1114]
# loss: 0.017634, [640]/[1114]
# loss: 0.025094, [960]/[1114]
# Test Error:
#  Accuracy: 5.7%, Avg loss: 0.008003
#
# Epoch: 19/300
# ------------------------------------------
# loss: 0.002472, [0]/[1114]
# loss: 0.014184, [320]/[1114]
# loss: 0.018250, [640]/[1114]
# loss: 0.007241, [960]/[1114]
# Test Error:
#  Accuracy: 6.5%, Avg loss: 0.006672
#
# Epoch: 20/300
# ------------------------------------------
# loss: 0.047282, [0]/[1114]
# loss: 0.002277, [320]/[1114]
# loss: 0.008301, [640]/[1114]
# loss: 0.070981, [960]/[1114]
# Test Error:
#  Accuracy: 6.5%, Avg loss: 0.007149
#
# Epoch: 21/300
# ------------------------------------------
# loss: 0.004781, [0]/[1114]
# loss: 0.000987, [320]/[1114]
# loss: 0.015757, [640]/[1114]
# loss: 0.010160, [960]/[1114]
# Test Error:
#  Accuracy: 6.5%, Avg loss: 0.006725
#
# Epoch: 22/300
# ------------------------------------------
# loss: 0.002945, [0]/[1114]
# loss: 0.001574, [320]/[1114]
# loss: 0.009268, [640]/[1114]
# loss: 0.012642, [960]/[1114]
# Test Error:
#  Accuracy: 5.7%, Avg loss: 0.006291
#
# Epoch: 23/300
# ------------------------------------------
# loss: 0.022082, [0]/[1114]
# loss: 0.002994, [320]/[1114]
# loss: 0.004342, [640]/[1114]
# loss: 0.006293, [960]/[1114]
# Test Error:
#  Accuracy: 5.4%, Avg loss: 0.006143
#
# Epoch: 24/300
# ------------------------------------------
# loss: 0.036603, [0]/[1114]
# loss: 0.000929, [320]/[1114]
# loss: 0.012073, [640]/[1114]
# loss: 0.015344, [960]/[1114]
# Test Error:
#  Accuracy: 5.7%, Avg loss: 0.006286
#
# Epoch: 25/300
# ------------------------------------------
# loss: 0.000551, [0]/[1114]
# loss: 0.007937, [320]/[1114]
# loss: 0.007832, [640]/[1114]
# loss: 0.008304, [960]/[1114]
# Test Error:
#  Accuracy: 6.5%, Avg loss: 0.006419
#
# Epoch: 26/300
# ------------------------------------------
# loss: 0.093431, [0]/[1114]
# loss: 0.003060, [320]/[1114]
# loss: 0.000640, [640]/[1114]
# loss: 0.019854, [960]/[1114]
# Test Error:
#  Accuracy: 5.7%, Avg loss: 0.005557
#
# Epoch: 27/300
# ------------------------------------------
# loss: 0.000538, [0]/[1114]
# loss: 0.000962, [320]/[1114]
# loss: 0.016196, [640]/[1114]
# loss: 0.005219, [960]/[1114]
# Test Error:
#  Accuracy: 6.8%, Avg loss: 0.005794
#
# Epoch: 28/300
# ------------------------------------------
# loss: 0.016057, [0]/[1114]
# loss: 0.000670, [320]/[1114]
# loss: 0.000976, [640]/[1114]
# loss: 0.005155, [960]/[1114]
# Test Error:
#  Accuracy: 6.8%, Avg loss: 0.005544
#
# Epoch: 29/300
# ------------------------------------------
# loss: 0.002469, [0]/[1114]
# loss: 0.001774, [320]/[1114]
# loss: 0.001960, [640]/[1114]
# loss: 0.009057, [960]/[1114]
# Test Error:
#  Accuracy: 6.5%, Avg loss: 0.005539
#
# Epoch: 30/300
# ------------------------------------------
# loss: 0.005362, [0]/[1114]
# loss: 0.001922, [320]/[1114]
# loss: 0.001007, [640]/[1114]
# loss: 0.004952, [960]/[1114]
# Test Error:
#  Accuracy: 6.8%, Avg loss: 0.005964
#
# Epoch: 31/300
# ------------------------------------------
# loss: 0.000478, [0]/[1114]
# loss: 0.000720, [320]/[1114]
# loss: 0.004039, [640]/[1114]
# loss: 0.000983, [960]/[1114]
# Test Error:
#  Accuracy: 6.1%, Avg loss: 0.005950
#
# Epoch: 32/300
# ------------------------------------------
# loss: 0.000630, [0]/[1114]
# loss: 0.000968, [320]/[1114]
# loss: 0.006272, [640]/[1114]
# loss: 0.020102, [960]/[1114]
# Test Error:
#  Accuracy: 6.1%, Avg loss: 0.003452
#
# Epoch: 33/300
# ------------------------------------------
# loss: 0.001531, [0]/[1114]
# loss: 0.000608, [320]/[1114]
# loss: 0.002669, [640]/[1114]
# loss: 0.001700, [960]/[1114]
# Test Error:
#  Accuracy: 5.7%, Avg loss: 0.005653
#
# Epoch: 34/300
# ------------------------------------------
# loss: 0.000307, [0]/[1114]
# loss: 0.001503, [320]/[1114]
# loss: 0.003475, [640]/[1114]
# loss: 0.001691, [960]/[1114]
# Test Error:
#  Accuracy: 6.5%, Avg loss: 0.004785
#
# Epoch: 35/300
# ------------------------------------------
# loss: 0.001526, [0]/[1114]
# loss: 0.000107, [320]/[1114]
# loss: 0.002396, [640]/[1114]
# loss: 0.001787, [960]/[1114]
# Test Error:
#  Accuracy: 7.2%, Avg loss: 0.006048
#
# Epoch: 36/300
# ------------------------------------------
# loss: 0.000506, [0]/[1114]
# loss: 0.000539, [320]/[1114]
# loss: 0.011621, [640]/[1114]
# loss: 0.021493, [960]/[1114]
# Test Error:
#  Accuracy: 5.0%, Avg loss: 0.007527
#
# Epoch: 37/300
# ------------------------------------------
# loss: 0.008143, [0]/[1114]
# loss: 0.019422, [320]/[1114]
# loss: 0.007845, [640]/[1114]
# loss: 0.004154, [960]/[1114]
# Test Error:
#  Accuracy: 6.5%, Avg loss: 0.006185
#
# Epoch: 38/300
# ------------------------------------------
# loss: 0.002166, [0]/[1114]
# loss: 0.000165, [320]/[1114]
# loss: 0.008453, [640]/[1114]
# loss: 0.000225, [960]/[1114]
# Test Error:
#  Accuracy: 5.7%, Avg loss: 0.007902
#
# Epoch: 39/300
# ------------------------------------------
# loss: 0.002864, [0]/[1114]
# loss: 0.000312, [320]/[1114]
# loss: 0.007227, [640]/[1114]
# loss: 0.000350, [960]/[1114]
# Test Error:
#  Accuracy: 4.7%, Avg loss: 0.008905
#
# Epoch: 40/300
# ------------------------------------------
# loss: 0.040856, [0]/[1114]
# loss: 0.008727, [320]/[1114]
# loss: 0.002382, [640]/[1114]
# loss: 0.017513, [960]/[1114]
# Test Error:
#  Accuracy: 6.5%, Avg loss: 0.006320
#
# Epoch: 41/300
# ------------------------------------------
# loss: 0.001211, [0]/[1114]
# loss: 0.000577, [320]/[1114]
# loss: 0.002958, [640]/[1114]
# loss: 0.080978, [960]/[1114]
# Test Error:
#  Accuracy: 6.5%, Avg loss: 0.008274
#
# Epoch: 42/300
# ------------------------------------------
# loss: 0.028159, [0]/[1114]
# loss: 0.000200, [320]/[1114]
# loss: 0.001346, [640]/[1114]
# loss: 0.000937, [960]/[1114]
# Test Error:
#  Accuracy: 6.5%, Avg loss: 0.006565
#
# Epoch: 43/300
# ------------------------------------------
# loss: 0.000251, [0]/[1114]
# loss: 0.000622, [320]/[1114]
# loss: 0.001245, [640]/[1114]
# loss: 0.002582, [960]/[1114]
# Test Error:
#  Accuracy: 5.7%, Avg loss: 0.007135
#
# Epoch: 44/300
# ------------------------------------------
# loss: 0.019514, [0]/[1114]
# loss: 0.000325, [320]/[1114]
# loss: 0.000909, [640]/[1114]
# loss: 0.070870, [960]/[1114]
# Test Error:
#  Accuracy: 7.5%, Avg loss: 0.006003
#
# Epoch: 45/300
# ------------------------------------------
# loss: 0.007994, [0]/[1114]
# loss: 0.004400, [320]/[1114]
# loss: 0.001149, [640]/[1114]
# loss: 0.048620, [960]/[1114]
# Test Error:
#  Accuracy: 6.1%, Avg loss: 0.004955
#
# Epoch: 46/300
# ------------------------------------------
# loss: 0.001304, [0]/[1114]
# loss: 0.003629, [320]/[1114]
